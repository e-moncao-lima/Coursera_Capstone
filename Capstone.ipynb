# %% [markdown]
# <h1 align="center"> Applied Data Science Capstone</h1>

# %% [markdown]
# <h4 align="Center">This notebook will be used mainly for the Applied Data Science Capstone Project by Coursera/IBM</h4>

# %% [markdown]
# <hr>
#
# ### Import libraries

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# ### Printing the statement

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
